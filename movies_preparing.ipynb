# %%
import pandas as pd

# %%
movies = pd.read_csv('./the-movies-dataset/movies_metadata.csv')
# Out:
# /var/folders/mf/7bhmyv7d2x56f5xg9qzhr2pr0000gn/T/ipykernel_44077/1302886729.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('./the-movies-dataset/movies_metadata.csv')

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies = movies.drop_duplicates(subset=['id'])
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
print(f"Количество строк:\n{len(movies)} #len(movies) - len(*) - функция отпределения длины в Python\n")
print(f"Или так:\n{movies.shape[0]} #movies.shape[0] - это типа размер 0-го (1-го) измерения")
# Out:
# Количество строк:
# 45436 #len(movies) - len(*) - функция отпределения длины в Python
#
# Или так:
# 45436 #movies.shape[0] - это типа размер 0-го (1-го) измерения

# %%
print(f"Количество столбцов: {movies.shape[1]} #movies.shape[1] - размер 1-го (2-го) измерения")
# Out:
# Количество столбцов: 24 #movies.shape[1] - размер 1-го (2-го) измерения

# %%
print(f"Количество ячеек:\n{movies.size} #movies.size")
print(f"Проверим:\nстолбцы*колонки = {movies.shape[1]}*{movies.shape[0]} = {movies.shape[1]*movies.shape[0]}")
# Out:
# Количество ячеек:
# 1090464 #movies.size
# Проверим:
# столбцы*колонки = 24*45436 = 1090464

# %%
print(f"Количество непустых ячеек для каждой колонки:\n{movies.count()} #movies.count()")
# Out:
# Количество непустых ячеек для каждой колонки:
# adult                    45436
# belongs_to_collection     4491
# budget                   45436
# genres                   45436
# homepage                  7777
# id                       45436
# imdb_id                  45419
# original_language        45425
# original_title           45436
# overview                 44482
# popularity               45431
# poster_path              45050
# production_companies     45433
# production_countries     45433
# release_date             45349
# revenue                  45430
# runtime                  45173
# spoken_languages         45430
# status                   45349
# tagline                  20401
# title                    45430
# video                    45430
# vote_average             45430
# vote_count               45430
# dtype: int64 #movies.count()

# %%
print(f"Что-то вроде шапки всей таблицы:\n{movies.head} #ratings.head") 
# Выбрана другая таблица, потому что у movies очень много колонок и они не помещаются
# Out:
# Что-то вроде шапки всей таблицы:
# <bound method NDFrame.head of        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
# ...

# %%
print("Первые 2 строки movies[:2] (то же что movies[0:2], где 0 можно опустить):")
movies[:2] # первые 10 строк
# Out:
# Первые 2 строки movies[:2] (то же что movies[0:2], где 0 можно опустить):
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# ...

# %%
print("C 4-й по 6-ю строки movies[4:6]")
movies[4:6] # c 4 по 10 строки
# Out:
# C 4-й по 6-ю строки movies[4:6]
#    adult                              belongs_to_collection    budget  \
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
#
#                                               genres homepage     id  \
# 4                     [{'id': 35, 'name': 'Comedy'}]      NaN  11862
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN    949
#
#      imdb_id original_language               original_title  \
# 4  tt0113041                en  Father of the Bride Part II
# 5  tt0113277                en                         Heat
#
#                                             overview  ... release_date  \
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
# 5  Obsessive master thief, Neil McCauley leads a ...  ...   1995-12-15
#
#        revenue runtime                                   spoken_languages  \
# ...

# %%
movies[10] 
# Нельзя просто написать movies[10], чтобы получить 10-ю строку
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/movies/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/PycharmProjects/movies/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/PycharmProjects/movies/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(f"Чтобы получить 10-ю строку нужно вызвать movies.iloc[10]:\n{movies.iloc[10]}")
# Out:
# Чтобы получить 10-ю строку нужно вызвать movies.iloc[10]:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                            62000000
# genres                   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                                                               NaN
# id                                                                    9087
# imdb_id                                                          tt0112346
# original_language                                                       en
# original_title                                      The American President
# overview                 Widowed U.S. president Andrew Shepherd, one of...
# popularity                                                        6.318445
# poster_path                               /lymPNGLZgPHuqM29rKMGV46ANij.jpg
# ...

# %%
print(f"Значение ячейки в 5 строке под колонкой 'budget':\n{movies.iloc[5]['budget']} # movies.iloc[5][‘budget’]")
# Out:
# Значение ячейки в 5 строке под колонкой 'budget':
# 60000000 # movies.iloc[5][‘budget’]

# %%
print(f"Список всех колонок:\n{movies.columns.values} # movies.columns.values")
# Out:
# Список всех колонок:
# ['adult' 'belongs_to_collection' 'budget' 'genres' 'homepage' 'id'
#  'imdb_id' 'original_language' 'original_title' 'overview' 'popularity'
#  'poster_path' 'production_companies' 'production_countries'
#  'release_date' 'revenue' 'runtime' 'spoken_languages' 'status' 'tagline'
#  'title' 'video' 'vote_average' 'vote_count'] # movies.columns.values

# %%
print(f"Подтаблица с 1 по 5 строку со 2 по 4 колонку:\n{movies.iloc[1:5, 2:4]} # movies.iloc[1:5, 2:4]")
# Out:
# Подтаблица с 1 по 5 строку со 2 по 4 колонку:
#      budget                                             genres
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4         0                     [{'id': 35, 'name': 'Comedy'}] # movies.iloc[1:5, 2:4]

# %%
movies[1:5][["budget", "title", "id"]]
# Out:
#      budget                        title     id
# 1  65000000                      Jumanji   8844
# 2         0             Grumpier Old Men  15602
# 3  16000000            Waiting to Exhale  31357
# 4         0  Father of the Bride Part II  11862

# %%
print(f"Подтаблица с единственной указанной колонкой:\n{movies['budget']} # movies['budget']")
print(f"Или так:\n{movies.budget} # movies.budget")
# Out:
# Подтаблица с единственной указанной колонкой:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45436, dtype: object # movies['budget']
# Или так:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45436, dtype: object # movies.budget

# %%
movies.iloc[5]['production_countries']
# Out:
# "[{'iso_3166_1': 'US', 'name': 'United States of America'}]"

# %%
import ast
import numpy as np

def string_to_code(line: str):
    if pd.isnull(line):
        return np.nan
    else:
        try:
            return ast.literal_eval(line)
        except:
            print("Except", line)
            return np.nan
json_columns = ['adult', 'belongs_to_collection', 'genres', 'production_companies', 'production_countries', 'spoken_languages']
for column in json_columns:
    print("Parse", column)
    movies[column] = movies[column].apply(string_to_code)
# Out:
# Parse adult
# Except  - Written by Ørnås
# Except  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.
# Except  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.
# Parse belongs_to_collection
# Parse genres
# Parse production_companies
# Parse production_countries
# Parse spoken_languages

# %%
# Этот трюк повторять не нужно. Только если есть необходимость
import json
from pandas.core.frame import DataFrame

"""
    Эта функция работает с таблицей (table:DataFrame), в которой колонка (column_name), 
    имеет cтроковые значения в формате json списка нескольких элементов 
    (например: 
        [
            {'iso_3166_1': 'US', 'name': 'United States of America'}, 
            {'iso_3166_1': 'RU', 'name': 'Russia'}
        ]
    ).
    Функция не меняет предоставленную таблицу (table:DataFrame).
    
    Данная функция преобразует значния всей колонки (column_name) в таблицу по типу:
    id		count	val0	val1
    123		2		US		RU
    
    Это первое возвращаемое значение функции. Всего их 2. О втором ниже.
    
    Название колонки id и ее значения (в примере: 123) повторяют переданную колонку 
    (main_column) для исходной таблицы (table:DataFrame).
    Создается колонка count, которая содержит количество значений из json-списка, 
    а в следующих нумерованых колонках содержатся сами значения, 
    добытые из элементов json-списка по ключу (main_json_field).
    Количество нумерованых колонок вычисляется динамически.
    Названия нумерованных колонок задается с помощью (new_indexed_column_name).
    
    Второе возвращаемое значение функции представляет собой легенду распарсеных ячеек.
    Создается если передан флаг create_legend=True, чтобы данные не были утрачены.
    Легенда также представляет собой таблицу следующего вида:
    iso_3166_1	name
    US			United States of America
    RU			Russia
    
"""
def parse_json_column(table:DataFrame, column_name:str, main_column:str, main_json_field:str, 
                         new_indexed_column_name:str="val", create_legend:bool=False):
    legend_columns = None
    legend = None
    main_to_child = []
    actual_max_count = 0

    for i, row in table.iterrows():
        value = row[column_name]
        entities = []
        count = 0
        try:
            count = len(value)

            if create_legend and legend_columns is None and count > 0:
                legend_columns = []
                legend = set()
                entity = value[0]
                for col in entity:
                    legend_columns.append(col)

            for entity_json in value:
                if create_legend and legend is not None:
                    values = tuple(str(value) for value in entity_json.values())
                    legend.add(values)
                entities.append(entity_json[main_json_field])

            actual_max_count = max(actual_max_count, len(entities))
        except:
            print("Except", value)
        
        main_to_child.append([row[main_column], count, *entities])
        
    for row in main_to_child:
        while len(row) < actual_max_count:
            row.append(np.nan)
            

    columns = [f"{new_indexed_column_name}{i}" for i in range(actual_max_count)]
    main_to_child = pd.DataFrame(main_to_child, columns=[main_column, 'count', *columns])
    legend = pd.DataFrame(legend, columns=legend_columns)
    
    return main_to_child, legend

films_to_counries, countries_legend = parse_json_column(movies, 
                                                        column_name='production_countries', 
                                                        main_column="id",
                                                        main_json_field = "iso_3166_1",
                                                        new_indexed_column_name="country",
                                                        create_legend=True)
# Out:
# Except nan
# Except 6.0
# Except nan
# Except 7.0
# Except nan
# Except 4.3

# %% [markdown]
# ![parse_json_column scheme](./resources/parse_json_table.png "Fun parse_json_table scheme")

# %%
countries_legend
# Out:
#     iso_3166_1                   name
# 0           NL            Netherlands
# 1           RS                 Serbia
# 2           PT               Portugal
# 3           SV            El Salvador
# 4           TH               Thailand
# ..         ...                    ...
# 156         TT    Trinidad and Tobago
# 157         KY         Cayman Islands
# 158         LT              Lithuania
# 159         JP                  Japan
# 160         PS  Palestinian Territory
#
# [161 rows x 2 columns]

# %%
films_to_counries
# Out:
#            id  count country0 country1 country2 country3 country4 country5  \
# 0         862      1       US      NaN      NaN      NaN      NaN      NaN
# 1        8844      1       US      NaN      NaN      NaN      NaN      NaN
# 2       15602      1       US      NaN      NaN      NaN      NaN      NaN
# 3       31357      1       US      NaN      NaN      NaN      NaN      NaN
# 4       11862      1       US      NaN      NaN      NaN      NaN      NaN
# ...       ...    ...      ...      ...      ...      ...      ...      ...
# 45431  439050      1       IR      NaN      NaN      NaN      NaN      NaN
# 45432  111109      1       PH      NaN      NaN      NaN      NaN      NaN
# 45433   67758      1       US      NaN      NaN      NaN      NaN      NaN
# 45434  227506      1       RU      NaN      NaN      NaN      NaN      NaN
# 45435  461257      1       GB      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
max_countries = films_to_counries["count"].max()
max_countries
# Out:
# 25

# %%
type(films_to_counries.groupby('count'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
c_count_to_f_count = films_to_counries.groupby('count').size().reset_index(name='films') 
c_count_to_f_count
# Out:
#     count  films
# 0       0   6285
# 1       1  32134
# 2       2   4871
# 3       3   1468
# 4       4    459
# 5       5    151
# 6       6     38
# 7       7     12
# 8       8      7
# 9       9      5
# 10     10      1
# 11     11      2
# 12     12      1
# 13     15      1
# 14     25      1

# %%
 # Проверяем, сходится ли сумма всех значений "films" с общим количеством фильмов, чтобы убедиться в целостности
print(c_count_to_f_count["films"].sum())
print(len(films_to_counries))
print(len(movies))
# Out:
# 45436
# 45436
# 45436

# %%
import matplotlib.pyplot as plt
# c_count_to_f_count.plot.hist(by=["films"])
plt.figure()
ax = c_count_to_f_count.plot.bar(title="Диаграмма 1: Количество фильмов произведенных разным количеством стран", 
                            x='count', y='films')
# ax.hlines(5500, -1, 15, color = 'r')

# %%
print(f"""
    Разберем значение для нас Диаграммы 1:
    Синие столбцы, - это количество (f) фильмов произведенных заданным количеством (count) стран,
    Иначе говоря f, - это количество строк в таблице films_to_counries, которые используют только count ячеек.
    То есть примерно 6000 строк не используют ячейки длоя указания страны, поскольку данных о производстве нет.
    И больше 30000 строк используют всего 1 столбец.
    Чем меньше высота графика для count, тем меньше фильмов используют count стоблцов.
    
    Это проблема, поскольку у нас может и использоваться лишняя память, да и просто таблица может сильно пустовать из-за
    чего ее вид может быть не репрезентативен.
""")
# Out:
#     Разберем значение для нас Диаграммы 1:
#     Синие столбцы, - это количество (f) фильмов произведенных заданным количеством (count) стран,
#     Иначе говоря f, - это количество строк в таблице films_to_counries, которые используют только count ячеек.
#     То есть примерно 6000 строк не используют ячейки длоя указания страны, поскольку данных о производстве нет.
#     И больше 30000 строк используют всего 1 столбец.
#     Чем меньше высота графика для count, тем меньше фильмов используют count стоблцов.
#
#     Это проблема, поскольку у нас может и использоваться лишняя память, да и просто таблица может сильно пустовать из-за
#     чего ее вид может быть не репрезентативен.

# %% [markdown]
# ![How the threshold makes since](./resources/threshold.png "How the threshold makes since")

# %%
# выведем диаграмму с логарифмической шкалой (шкала Рихтера), чтобы понимать во сколько раз столбцы больше друг друга
c_count_to_f_count.plot.bar(title="Диаграмма 1.1: То же что Диаграмма 1, но логарифмическая ", 
                            x='count', y='films', logy=True)

# %%
# чтобы понять, на сколько велика проблема, послитаем реальное количество простаивающих ячеек
full_filled_cells_count = len(films_to_counries)*max_countries
usefull_cells = (c_count_to_f_count["films"] * c_count_to_f_count["count"]).sum()
full_filled_cells_count - usefull_cells
# Out:
# 1086532

# %%
print("""Нужно решить проблему простоя ячеек. Исследуем несколько методов:
    1. Поскольку в нашем случае, чем меньше количество стран производителей (count), тем меньше ячеек задействовано (кроме 0), 
        мы можем разделить таблицу films_to_counries на две. В первой будут храниться фильмы, которые произведены малым
        количеством стран, соответственно количество ячеек там можно сократить, но количество сторк там будет большим. 
        Во второй таблице будет сильно меньше строк, но количество столбцов будет больше.
        Этот вариант не очень хороший по причине, которую мы увидим позже, а пока что в целях практики можно попробовать и его.
    2. Перекроить нашу таблицу так, чтобы в таблице с фильмами столбцы стран производителей были представлены строками. 
        Эту таблицу также стоит вынести отдельно от общей таблицы.
        
    Мы начнем с первого варианта, Рассмотрим его недочеты и придем ко второму.
""")
# Out:
# Нужно решить проблему простоя ячеек. Исследуем несколько методов:
#     1. Поскольку в нашем случае, чем меньше количество стран производителей (count), тем меньше ячеек задействовано (кроме 0),
#         мы можем разделить таблицу films_to_counries на две. В первой будут храниться фильмы, которые произведены малым
#         количеством стран, соответственно количество ячеек там можно сократить, но количество сторк там будет большим.
#         Во второй таблице будет сильно меньше строк, но количество столбцов будет больше.
#         Этот вариант не очень хороший по причине, которую мы увидим позже, а пока что в целях практики можно попробовать и его.
#     2. Перекроить нашу таблицу так, чтобы в таблице с фильмами столбцы стран производителей были представлены строками.
#         Эту таблицу также стоит вынести отдельно от общей таблицы.
#
#     Мы начнем с первого варианта, Рассмотрим его недочеты и придем ко второму.

# %%
# Разделение таблицы films_to_counries на две поменьше.
# Выберем порог, по которому будем делить таблицу. Будем выбирать самый выгодный с точки зрения экономии столбцов
benefit_threshold = 0
benefit_max = 0
for current_countries_count in range(1, max_countries):
    current_benefit = (max_countries - current_countries_count)*\
        len(films_to_counries[films_to_counries["count"] <= current_countries_count])
    if current_benefit > benefit_max:
        benefit_max = current_benefit
        benefit_threshold = current_countries_count
    
print(f"При пороге равном {benefit_threshold} будет достигнута наибольшая выгода в {benefit_max} ячеек!")
# Out:
# При пороге равном 2 будет достигнута наибольшая выгода в 995670 ячеек!

# %%
films_to_counries
# Out:
#            id  count country0 country1 country2 country3 country4 country5  \
# 0         862      1       US      NaN      NaN      NaN      NaN      NaN
# 1        8844      1       US      NaN      NaN      NaN      NaN      NaN
# 2       15602      1       US      NaN      NaN      NaN      NaN      NaN
# 3       31357      1       US      NaN      NaN      NaN      NaN      NaN
# 4       11862      1       US      NaN      NaN      NaN      NaN      NaN
# ...       ...    ...      ...      ...      ...      ...      ...      ...
# 45431  439050      1       IR      NaN      NaN      NaN      NaN      NaN
# 45432  111109      1       PH      NaN      NaN      NaN      NaN      NaN
# 45433   67758      1       US      NaN      NaN      NaN      NaN      NaN
# 45434  227506      1       RU      NaN      NaN      NaN      NaN      NaN
# 45435  461257      1       GB      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
films_to_counries_temp = films_to_counries
columns = [f"country{i}" for i in range(benefit_threshold, max_countries)]
films_to_counries, films_to_counries_overweight = \
    films_to_counries_temp.drop(columns=columns), \
    films_to_counries_temp[films_to_counries_temp["count"] > benefit_threshold].reset_index()
## films_to_counries_temp = None

# %%
films_to_counries
# Out:
#            id  count country0 country1
# 0         862      1       US      NaN
# 1        8844      1       US      NaN
# 2       15602      1       US      NaN
# 3       31357      1       US      NaN
# 4       11862      1       US      NaN
# ...       ...    ...      ...      ...
# 45431  439050      1       IR      NaN
# 45432  111109      1       PH      NaN
# 45433   67758      1       US      NaN
# 45434  227506      1       RU      NaN
# 45435  461257      1       GB      NaN
#
# [45436 rows x 4 columns]

# %%
films_to_counries_overweight
# Out:
#       index      id  count country0 country1 country2 country3 country4  \
# 0        14    1408      4       FR       DE       IT       US      NaN
# 1        28     902      3       FR       DE       ES      NaN      NaN
# 2        52   49133      3       IT       FR       CH      NaN      NaN
# 3        57   11010      3       BE       FR       IT      NaN      NaN
# 4        75    9102      3       CA       JP       US      NaN      NaN
# ...     ...     ...    ...      ...      ...      ...      ...      ...
# 2141  45270   58133      3       FR       DE       ES      NaN      NaN
# 2142  45285  152912      3       PL       CZ       SK      NaN      NaN
# 2143  45314   90063      3       CU       DE       ES      NaN      NaN
# 2144  45336   40467      3       EG       IT       US      NaN      NaN
# 2145  45430   30840      4       CA       DE       GB       US      NaN
#
#      country5 country6  ... country15 country16 country17 country18 country19  \
# ...

# %%
print("""
    Теперь у нас две таблицы и сэкономлено много простаивающих ячеек.
    Анализировать будет не сильно сложнее. Если мы захотим получить информацию о странах-производителях, 
    то для фильмов с количеством стран <= 2, мы будем искать инфу в films_to_counries, 
    а для остальных в films_to_counries_overweight.
""")
# Out:
#     Теперь у нас две таблицы и сэкономлено много простаивающих ячеек.
#     Анализировать будет не сильно сложнее. Если мы захотим получить информацию о странах-производителях,
#     то для фильмов с количеством стран <= 2, мы будем искать инфу в films_to_counries,
#     а для остальных в films_to_counries_overweight.

# %%
print("""
    Поскольку первая таблица получилась films_to_counries весьма маленькая, но ее можно приклеить к исходной таблице movies.
    Сейчас мы это сделаем, но поскольку мы заведомо знаем, что не остановимся на этом варианте, 
    то результат склейки применим к временной таблице, которую сейчас создадим.
""")
# Out:
#     Поскольку первая таблица получилась films_to_counries весьма маленькая, но ее можно приклеить к исходной таблице movies.
#     Сейчас мы это сделаем, но поскольку мы заведомо знаем, что не остановимся на этом варианте,
#     то результат склейки применим к временной таблице, которую сейчас создадим.

# %%
movies_with_2_countries = movies.merge(films_to_counries, on=['id'])
movies_with_2_countries = movies_with_2_countries.drop(columns='production_countries') 
movies_with_2_countries.columns.values
# Out:
# array(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'id', 'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count', 'count',
#        'country0', 'country1'], dtype=object)

# %%
movies_with_2_countries.rename(columns = {'count':'countries_count'}, inplace = True)
movies_with_2_countries.columns.values
# Out:
# array(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'id', 'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count',
#        'countries_count', 'country0', 'country1'], dtype=object)

# %%
movies_with_2_countries
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45431  False                                                NaN         0
# 45432  False                                                NaN         0
# 45433  False                                                NaN         0
# 45434  False                                                NaN         0
# 45435  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
print("""
    Проблема решена, сэкономлено много пустых ячеек. 
    Но так ли хорошо теперь выглядит наша вторая таблица films_to_counries_overweight ?
""")
films_to_counries_overweight
# Out:
#     Проблема решена, сэкономлено много пустых ячеек.
#     Но так ли хорошо теперь выглядит наша вторая таблица films_to_counries_overweight ?
#       index      id  count country0 country1 country2 country3 country4  \
# 0        14    1408      4       FR       DE       IT       US      NaN
# 1        28     902      3       FR       DE       ES      NaN      NaN
# 2        52   49133      3       IT       FR       CH      NaN      NaN
# 3        57   11010      3       BE       FR       IT      NaN      NaN
# 4        75    9102      3       CA       JP       US      NaN      NaN
# ...     ...     ...    ...      ...      ...      ...      ...      ...
# 2141  45270   58133      3       FR       DE       ES      NaN      NaN
# 2142  45285  152912      3       PL       CZ       SK      NaN      NaN
# 2143  45314   90063      3       CU       DE       ES      NaN      NaN
# 2144  45336   40467      3       EG       IT       US      NaN      NaN
# ...

# %%
print("""
    Строк гораздо меньше, но все еще много ячеек NaN
    Взглянем на диаграмму
""")
c_count_to_f_count_more_than_2 = films_to_counries_overweight.groupby('count').size().reset_index(name='films') 
plt.figure()
c_count_to_f_count_more_than_2.plot.bar(title="Диаграмма 2: Количество фильмов произведенных разным количеством стран (где count > 2)", 
                            x='count', y='films')
# Out:
#     Строк гораздо меньше, но все еще много ячеек NaN
#     Взглянем на диаграмму

# %%
print("""
    Из диаграммы можем сделать вывод, проблема осталась, но теперь на меньшем масштабе.
    Простаивающих ячеек все еще сильно больше чем хотелось бы. 
    Большинству фильмов этой таблицы хватило бы 3-х столбцов, 
    а 4-й и остальные нужны уже на >1000 фильмам меньше, что значит простой более чем 1000*(25-3)=22000 ячеек.
    Можно снова применить знакомый способ с разбиением, но даже по диаграмме видно, 
    что и на следующем этапе и на следующем проблема буде повторяться, пока мы не создадим несколько десятков таблиц, 
    после чего мы сэкономим очень много ячеек, но точно запутаемся в таблицах.
    
    На самом деле примененный метод хорош, чтобы загасить всплеск в начале график, 
    при условии, что оставшийся график примерно неизменен, т.е. если бы на 1-2 столбцах был всплеск,
    а начиная с 3-го все столбы были бы +- на одном уровне, тогда трюк с разделением был бы эффективен.
    
    Но в нашем случае это не так, а значит нужно найти другой способ организации данных
    Возможно, лучше сделать одну отдельную таблицу fimls_to_countries, в которой будут 2 колонки film_id и country_id, 
    И вместо того, чтобы городить много лишних колонок, мы будем городить много строк, где все нужные.
    Тогда, запросив фильм по film_id, мы получим набор строк, обозначающих страны.
""")
# Out:
#     Из диаграммы можем сделать вывод, проблема осталась, но теперь на меньшем масштабе.
#     Простаивающих ячеек все еще сильно больше чем хотелось бы.
#     Большинству фильмов этой таблицы хватило бы 3-х столбцов,
#     а 4-й и остальные нужны уже на >1000 фильмам меньше, что значит простой более чем 1000*(25-3)=22000 ячеек.
#     Можно снова применить знакомый способ с разбиением, но даже по диаграмме видно,
#     что и на следующем этапе и на следующем проблема буде повторяться, пока мы не создадим несколько десятков таблиц,
#     после чего мы сэкономим очень много ячеек, но точно запутаемся в таблицах.
#
#     На самом деле примененный метод хорош, чтобы загасить всплеск в начале график,
#     при условии, что оставшийся график примерно неизменен, т.е. если бы на 1-2 столбцах был всплеск,
#     а начиная с 3-го все столбы были бы +- на одном уровне, тогда трюк с разделением был бы эффективен.
#
# ...

# %%
# Реализуем второй вариант организации данных о странах
# Сначала попробуем на примере одной строки
temp = films_to_counries_temp[films_to_counries_temp["count"] > 23]
columns = [f"country{i}" for i in range(max_countries)]
films_to_counries_plural = pd.melt(temp, id_vars=["id"], value_vars=columns, var_name='del_it', value_name='iso_3166_1')
films_to_counries_plural = films_to_counries_plural.drop(columns=["del_it"])
films_to_counries_plural
# Out:
#       id iso_3166_1
# 0   8985         AT
# 1   8985         BE
# 2   8985         CY
# 3   8985         CZ
# 4   8985         DK
# 5   8985         EE
# 6   8985         FI
# 7   8985         FR
# 8   8985         DE
# 9   8985         GR
# 10  8985         HU
# 11  8985         IE
# 12  8985         IT
# 13  8985         LV
# 14  8985         LT
# 15  8985         LU
# 16  8985         MT
# 17  8985         NL
# 18  8985         PL
# 19  8985         PT
# 20  8985         SK
# 21  8985         SI
# 22  8985         ES
# 23  8985         SE
# 24  8985         GB

# %%
films_to_counries_temp
# Out:
#            id  count country0 country1 country2 country3 country4 country5  \
# 0         862      1       US      NaN      NaN      NaN      NaN      NaN
# 1        8844      1       US      NaN      NaN      NaN      NaN      NaN
# 2       15602      1       US      NaN      NaN      NaN      NaN      NaN
# 3       31357      1       US      NaN      NaN      NaN      NaN      NaN
# 4       11862      1       US      NaN      NaN      NaN      NaN      NaN
# ...       ...    ...      ...      ...      ...      ...      ...      ...
# 45431  439050      1       IR      NaN      NaN      NaN      NaN      NaN
# 45432  111109      1       PH      NaN      NaN      NaN      NaN      NaN
# 45433   67758      1       US      NaN      NaN      NaN      NaN      NaN
# 45434  227506      1       RU      NaN      NaN      NaN      NaN      NaN
# 45435  461257      1       GB      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
# Повторим со всей таблицей
films_to_counries_plural = pd.melt(films_to_counries_temp, 
                                   id_vars=["id"], 
                                   value_vars=[f"country{i}" for i in range(max_countries)], 
                                   var_name='del_it', 
                                   value_name='iso_3166_1')
films_to_counries_plural = films_to_counries_plural[films_to_counries_plural["iso_3166_1"].notnull()]
films_to_counries_plural = films_to_counries_plural.drop(columns=["del_it"])
films_to_counries_plural
# Out:
#             id iso_3166_1
# 0          862         US
# 1         8844         US
# 2        15602         US
# 3        31357         US
# 4        11862         US
# ...        ...        ...
# 930941    8985         SK
# 976377    8985         SI
# 1021813   8985         ES
# 1067249   8985         SE
# 1112685   8985         GB
#
# [49368 rows x 2 columns]

# %%
print("""
    Готово! Ограничившись парой вызовов pd функций мы добились желаемого результата
    И теперь можем вовсе удалить из оригинальной таблицы movies данные о странах, 
    потому что они все в этй таблице, причем уже распарсеные.
    
    Попробуем демонстративно достать данные из этой таблицы для какого-то фильма, чтобы потом гипотеттически их использовать.
""")
movies = movies.drop(columns=["production_countries"])
#выбали произвольный фильм с большим количеством стран (добыли его id)
some_film_id = '12242'
some_film = movies[movies["id"] == some_film_id].iloc[0]
some_film_countries = films_to_counries_plural[films_to_counries_plural["id"] == some_film_id]
some_film_countries
# Out:
#     Готово! Ограничившись парой вызовов pd функций мы добились желаемого результата
#     И теперь можем вовсе удалить из оригинальной таблицы movies данные о странах,
#     потому что они все в этй таблице, причем уже распарсеные.
#
#     Попробуем демонстративно достать данные из этой таблицы для какого-то фильма, чтобы потом гипотеттически их использовать.
#            id iso_3166_1
# 23233   12242         HK
# 68669   12242         JP
# 114105  12242         KZ
# 159541  12242         MY
# 204977  12242         RU
# 250413  12242         SG
# 295849  12242         KR
# 341285  12242         TW
# 386721  12242         US

# %%
full_countries_names = ", ".join([countries_legend[countries_legend["iso_3166_1"] == country].iloc[0]["name"] \
                        for country in some_film_countries["iso_3166_1"].array])

print(f"""
    Таким незамысловатым способом мы выяснили, что произвольный фильм '{some_film["title"]}' 
    был произведен {some_film_countries["iso_3166_1"].count()}-ю странами, среди которых:
    {full_countries_names}
    
    Мы конечно и пару часов на глаз могли это сделать, 
    но теперь наши данные отформатированы удобным для автоматической и ручной обработки
""")
# Out:
#     Таким незамысловатым способом мы выяснили, что произвольный фильм 'Mulan II'
#     был произведен 9-ю странами, среди которых:
#     Hong Kong, Japan, Kazakhstan, Malaysia, Russia, Singapore, South Korea, Taiwan, United States of America
#
#     Мы конечно и пару часов на глаз могли это сделать,
#     но теперь наши данные отформатированы удобным для автоматической и ручной обработки

# %%
# Посмотрим, какие еще колонки позволят нам провернуть то же самое
for col in movies.columns.values:
    print(f"{col} ->", movies.iloc[5][col])
# Out:
# adult -> False
# belongs_to_collection -> nan
# budget -> 60000000
# genres -> [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]
# homepage -> nan
# id -> 949
# imdb_id -> tt0113277
# original_language -> en
# original_title -> Heat
# overview -> Obsessive master thief, Neil McCauley leads a top-notch crew on various insane heists throughout Los Angeles while a mentally unstable detective, Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.
# popularity -> 17.924927
# poster_path -> /zMyfPUelumio3tiDKPffaUpsQTD.jpg
# production_companies -> [{'name': 'Regency Enterprises', 'id': 508}, {'name': 'Forward Pass', 'id': 675}, {'name': 'Warner Bros.', 'id': 6194}]
# release_date -> 1995-12-15
# revenue -> 187436818.0
# runtime -> 170.0
# ...

# %%
# Колонка "spoken_languages"
films_to_languages, languages_legend = parse_json_column(movies,
                                                        column_name='spoken_languages',  
                                                        main_column="id",
                                                        main_json_field = "iso_639_1",
                                                        new_indexed_column_name="language",
                                                        create_legend=True)
# Out:
# Except nan
# Except nan
# Except nan
# Except nan
# Except nan
# Except nan

# %%
languages_legend
# Out:
#     iso_639_1         name
# 0          cy      Cymraeg
# 1          af    Afrikaans
# 2          el     ελληνικά
# 3          sl  Slovenščina
# 4          sh
# ..        ...          ...
# 128        ka      ქართული
# 129        tn
# 130        fy
# 131        ta        தமிழ்
# 132        tg
#
# [133 rows x 2 columns]

# %%
languages_legend[languages_legend["iso_639_1"] == "ru"]
# Out:
#     iso_639_1     name
# 127        ru  Pусский

# %%
films_to_languages
# Out:
#            id  count language0 language1 language2 language3 language4  \
# 0         862      1        en       NaN       NaN       NaN       NaN
# 1        8844      2        en        fr       NaN       NaN       NaN
# 2       15602      1        en       NaN       NaN       NaN       NaN
# 3       31357      1        en       NaN       NaN       NaN       NaN
# 4       11862      1        en       NaN       NaN       NaN       NaN
# ...       ...    ...       ...       ...       ...       ...       ...
# 45431  439050      1        fa       NaN       NaN       NaN       NaN
# 45432  111109      1        tl       NaN       NaN       NaN       NaN
# 45433   67758      1        en       NaN       NaN       NaN       NaN
# 45434  227506      0       NaN       NaN       NaN       NaN       NaN
# 45435  461257      1        en       NaN       NaN       NaN       NaN
#
#       language5 language6 language7  ... language9 language10 language11  \
# ...

# %%
languages_max = films_to_languages["count"].max()

# %%
films_to_languages_plural = pd.melt(films_to_languages, 
                                   id_vars=["id"], 
                                   value_vars=[f"language{i}" for i in range(languages_max)], 
                                   var_name='del_it', 
                                   value_name='iso_639_1')
films_to_languages_plural = films_to_languages_plural[films_to_languages_plural["iso_639_1"].notnull()]
films_to_languages_plural = films_to_languages_plural.drop(columns=["del_it"])
films_to_languages_plural

movies = movies.drop(columns=["spoken_languages"])
movies = movies.drop(columns=["original_language"])

some_film_id = '949'
some_film = movies[movies["id"] == some_film_id].iloc[0]
some_film_languages = films_to_languages_plural[films_to_languages_plural["id"] == some_film_id]
some_film_languages

full_languages_names = ", ".join([languages_legend[languages_legend["iso_639_1"] == lang].iloc[0]["name"] \
                        for lang in some_film_languages["iso_639_1"].array])

print(f"""
    Произвели тот же фокус с языками, теперь у нас несколько удобных таблиц для работы с ними.
    Ради проверки исследуем произвольный фильм '{some_film["title"]}' 
    который был переведен на {some_film_languages["iso_639_1"].count()} языков, среди которых:
    {full_languages_names}
""")
# Out:
#     Произвели тот же фокус с языками, теперь у нас несколько удобных таблиц для работы с ними.
#     Ради проверки исследуем произвольный фильм 'Heat'
#     который был переведен на 2 языков, среди которых:
#     English, Español

# %%
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# Поместим код по разбиению на таблицы в отдельную функцию, чтобы сократить количество дублирований.
# Ps Стоило это сделать сразу, но так примеры более доходчивы
def extruct_plural_map_df(table:DataFrame, column_name:str, main_column:str, main_json_field:str, 
                         create_legend:bool=False):
    new_indexed_column_name = f"val_{column_name}"
    map_df, legend = parse_json_column(table=table,
                                       column_name=column_name,  
                                       main_column=main_column,
                                       main_json_field = main_json_field,
                                       new_indexed_column_name=new_indexed_column_name,
                                       create_legend=create_legend)
    max_count = map_df["count"].max()

    plural_map = pd.melt(map_df, id_vars=[main_column], 
                         value_vars=[f"{new_indexed_column_name}{i}" for i in range(max_count)], 
                         var_name='del_it', value_name=main_json_field)
    plural_map = plural_map[plural_map[main_json_field].notnull()]
    plural_map = plural_map.drop(columns=["del_it"])

    table = table.drop(columns=[column_name])
    
    return (table, plural_map, legend)

# %%
# И снова тот же фокус с жанрами
# пример значения ячейки
# genres -> [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, 
#            {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]

movies.rename(columns = {'id':'movie_id'}, inplace = True)
movies, films_to_genres_plural, genres_legend = extruct_plural_map_df(table=movies, column_name="genres", 
                                                                      main_column="movie_id", main_json_field="id",
                                                                      create_legend=True)

some_film_id = '949'
some_film = movies[movies["movie_id"] == some_film_id].iloc[0]
some_film_genres = films_to_genres_plural[films_to_genres_plural["movie_id"] == some_film_id]

genres = [genre for genre in some_film_genres["id"].array]

full_genres_names = ", ".join([genres_legend[genres_legend["id"] == str(int(genre))].iloc[0]["name"] \
                        for genre in some_film_genres["id"].array])

print(f"""
    По классике. Фильм '{some_film["title"]}' в {some_film_genres["id"].count()} жанрах, среди которых:
    {full_genres_names}
""")
# Out:
#     По классике. Фильм 'Heat' в 4 жанрах, среди которых:
#     Action, Crime, Drama, Thriller

# %%
genres_legend
# Out:
#                                        id             name
# 0                                      53         Thriller
# 1                                   10402            Music
# 2                                      37          Western
# 3                              The Cartel            23822
# 4                                      14          Fantasy
# 5                                 Aniplex             2883
# 6                                      99      Documentary
# 7                                      36          History
# 8                                      12        Adventure
# 9                        Sentai Filmworks            33751
# 10                                     27           Horror
# 11                                     28           Action
# 12                                   9648          Mystery
# 13                                     16        Animation
# 14                                     18            Drama
# ...

# %%
films_to_genres_plural
# Out:
#        movie_id       id
# 0           862     16.0
# 1          8844     12.0
# 2         15602  10749.0
# 3         31357     35.0
# 4         11862     35.0
# ...         ...      ...
# 313934   220447     18.0
# 317930    90063     16.0
# 326135    11052  10751.0
# 352412    65592     35.0
# 353711   325712     53.0
#
# [91027 rows x 2 columns]

# %%
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                    homepage movie_id    imdb_id  \
# ...

# %%
movies.iloc[5]["production_companies"]
# Out:
# [{'name': 'Regency Enterprises', 'id': 508},
#  {'name': 'Forward Pass', 'id': 675},
#  {'name': 'Warner Bros.', 'id': 6194}]

# %%
movies, films_to_companies_plural, companies_legend = extruct_plural_map_df(table=movies, 
                                                                            column_name="production_companies",
                                                                            main_column="movie_id", 
                                                                            main_json_field="id",
                                                                            create_legend=True)
# Out:
# Except nan
# Except False
# Except nan
# Except False
# Except nan
# Except False

# %%
some_film_id = '949'
some_film = movies[movies["movie_id"] == some_film_id].iloc[0]
some_film_companies = films_to_companies_plural[films_to_companies_plural["movie_id"] == some_film_id]

companies = [company for company in some_film_companies["id"].array]

full_companies_names = ", ".join([companies_legend[companies_legend["id"] == str(int(company))].iloc[0]["name"] \
                        for company in some_film_companies["id"].array])

print(f"""
    Фильм '{some_film["title"]}' произведен {some_film_companies["id"].count()} компаниями, среди которых:
    {full_companies_names}
""")
# Out:
#     Фильм 'Heat' произведен 3 компаниями, среди которых:
#     Regency Enterprises, Forward Pass, Warner Bros.

# %%
# movies_temp = movies
# movies_temp.iloc[10]["belongs_to_collection"] = movies["belongs_to_collection"].apply(lambda x: len(x) if x is dict else -1)
# movies_temp["belongs_to_collection"].unique()
movies.iloc[4]["belongs_to_collection"]
# Out:
# {'id': 96871,
#  'name': 'Father of the Bride Collection',
#  'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg',
#  'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}

# %%
def mark_type(x):
    if type(x) is list:
        return -len(x)
    elif type(x) is dict:
        return 1
    else:
        return 0

movies["belongs_to_collection"].apply(mark_type).unique()
# Out:
# array([1, 0])

# %%
films_to_collections = movies[["movie_id", "belongs_to_collection"]]
films_to_collections = films_to_collections[films_to_collections["belongs_to_collection"].notnull()]
films_to_collections[['collection_id', 
    'collection_name', 
    'collection_poster_path', 
    'collection_backdrop_path']] = films_to_collections["belongs_to_collection"].apply(lambda cell: \
                                    pd.Series([cell["id"], cell["name"], cell["poster_path"], cell["backdrop_path"]])\
                                    if type(cell) is dict else pd.Series([np.nan, np.nan, np.nan, np.nan]))

films_to_collections
# Out:
#       movie_id                              belongs_to_collection  \
# 0          862  {'id': 10194, 'name': 'Toy Story Collection', ...
# 2        15602  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 4        11862  {'id': 96871, 'name': 'Father of the Bride Col...
# 9          710  {'id': 645, 'name': 'James Bond Collection', '...
# 12       21032  {'id': 117693, 'name': 'Balto Collection', 'po...
# ...        ...                                                ...
# 45355    24568  {'id': 37261, 'name': 'The Carry On Collection...
# 45358    19307  {'id': 37261, 'name': 'The Carry On Collection...
# 45369    21251  {'id': 37261, 'name': 'The Carry On Collection...
# 45371   460135  {'id': 477208, 'name': 'DC Super Hero Girls Co...
# 45382   182030  {'id': 200641, 'name': 'Red Lotus Collection',...
#
#        collection_id                 collection_name  \
# 0            10194.0            Toy Story Collection
# 2           119050.0       Grumpy Old Men Collection
# ...

# %%
movies = movies.drop(columns=["belongs_to_collection"])
films_to_collections = films_to_collections.drop(columns=["belongs_to_collection"])
films_to_collections
# Out:
#       movie_id  collection_id                 collection_name  \
# 0          862        10194.0            Toy Story Collection
# 2        15602       119050.0       Grumpy Old Men Collection
# 4        11862        96871.0  Father of the Bride Collection
# 9          710          645.0           James Bond Collection
# 12       21032       117693.0                Balto Collection
# ...        ...            ...                             ...
# 45355    24568        37261.0         The Carry On Collection
# 45358    19307        37261.0         The Carry On Collection
# 45369    21251        37261.0         The Carry On Collection
# 45371   460135       477208.0  DC Super Hero Girls Collection
# 45382   182030       200641.0            Red Lotus Collection
#
#                  collection_poster_path          collection_backdrop_path
# 0      /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# ...

# %%
movies[movies.original_title != movies.title][["original_title", "title"]]
# Out:
#                          original_title                      title
# 28           La Cité des Enfants Perdus  The City of Lost Children
# 29                            摇啊摇，摇到外婆桥             Shanghai Triad
# 32     Guillaumet, les ailes du courage           Wings of Courage
# 57                           Il postino                The Postman
# 58                     Le confessionnal           The Confessional
# ...                                 ...                        ...
# 45453                               Maa                        Mom
# 45455        San Michele aveva un gallo  St. Michael Had a Rooster
# 45461                           رگ خواب                     Subdue
# 45462               Siglo ng Pagluluwal        Century of Birthing
# 45464               Satana likuyushchiy           Satan Triumphant
#
# [11394 rows x 2 columns]

# %%
# movies.groupby(["adult"])[["movie_id","adult"]].count().rename(columns = {'adult':'count'}, inplace = False)

# %%
# movies[(movies["adult"] == True)]

# %%
# movies[(movies["adult"] == "True")]

# %%
# movies = movies[(movies["adult"] == "True") | (movies["adult"] == "False")]

# %%
# movies["adult"] = movies["adult"].astype('bool')

# %%
movies.status.unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
movies[movies.status != "Released"]
# Out:
#        adult budget                      homepage movie_id    imdb_id  \
# 189    False      0                           NaN    56088  tt0114435
# 682    False      0                           NaN    48260  tt0112604
# 767    False      0   http://www.tsquare.tv/film/    52059  tt0113147
# 775    False      0                           NaN    44495  tt0072362
# 1032   False      0                           NaN    38191  tt0117781
# ...      ...    ...                           ...      ...        ...
# 45109  False      0                           NaN    63568  tt0147806
# 45159  False      0                           NaN    41811  tt0099480
# 45207  False      0  https://columbusthemovie.com   414453  tt5990474
# 45289  False      0                           NaN    87229  tt1524553
# 45442  False      0                           NaN    44330  tt0135690
#
#                    original_title  \
# 189                      The Show
# 682                Butterfly Kiss
# ...

# %%
movies_stuff = movies[["adult", "homepage", "imdb_id", "original_title", "overview", "poster_path", "status", "tagline", "video"]]
movies_stuff
# Out:
#        adult                              homepage    imdb_id  \
# 0      False  http://toystory.disney.com/toy-story  tt0114709
# 1      False                                   NaN  tt0113497
# 2      False                                   NaN  tt0113228
# 3      False                                   NaN  tt0114885
# 4      False                                   NaN  tt0113041
# ...      ...                                   ...        ...
# 45461  False  http://www.imdb.com/title/tt6209470/  tt6209470
# 45462  False                                   NaN  tt2028550
# 45463  False                                   NaN  tt0303758
# 45464  False                                   NaN  tt0008536
# 45465  False                                   NaN  tt6980792
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...

# %%
movies = movies.drop(columns=["adult", "homepage", "imdb_id", "original_title", "overview", "poster_path", "status", "tagline", "video"])
movies
# Out:
#          budget movie_id popularity release_date      revenue  runtime  \
# 0      30000000      862  21.946943   1995-10-30  373554033.0     81.0
# 1      65000000     8844  17.015539   1995-12-15  262797249.0    104.0
# 2             0    15602    11.7129   1995-12-22          0.0    101.0
# 3      16000000    31357   3.859495   1995-12-22   81452156.0    127.0
# 4             0    11862   8.387519   1995-02-10   76578911.0    106.0
# ...         ...      ...        ...          ...          ...      ...
# 45461         0   439050   0.072051          NaN          0.0     90.0
# 45462         0   111109   0.178241   2011-11-17          0.0    360.0
# 45463         0    67758   0.903007   2003-08-01          0.0     90.0
# 45464         0   227506   0.003503   1917-10-21          0.0     87.0
# 45465         0   461257   0.163015   2017-06-09          0.0     75.0
#
#                              title  vote_average  vote_count
# ...

# %%
movies = movies[["movie_id", "title", "release_date", "budget", "revenue", 
                 "runtime", "popularity", "vote_average", "vote_count"]]
movies
# Out:
#       movie_id                        title release_date    budget  \
# 0          862                    Toy Story   1995-10-30  30000000
# 1         8844                      Jumanji   1995-12-15  65000000
# 2        15602             Grumpier Old Men   1995-12-22         0
# 3        31357            Waiting to Exhale   1995-12-22  16000000
# 4        11862  Father of the Bride Part II   1995-02-10         0
# ...        ...                          ...          ...       ...
# 45461   439050                       Subdue          NaN         0
# 45462   111109          Century of Birthing   2011-11-17         0
# 45463    67758                     Betrayal   2003-08-01         0
# 45464   227506             Satan Triumphant   1917-10-21         0
# 45465   461257                     Queerama   2017-06-09         0
#
#            revenue  runtime popularity  vote_average  vote_count
# 0      373554033.0     81.0  21.946943           7.7      5415.0
# ...

# %%
import re

movies = movies[movies['release_date']\
                .apply(lambda x: type(x) is str and bool(re.match(r'\d\d\d\d-\d\d?-\d\d?', x)))]

# %%
movies['release_date'] = pd.c(movies['release_date'], format='%Y-%m-%d')
# Out:
# /var/folders/mf/7bhmyv7d2x56f5xg9qzhr2pr0000gn/T/ipykernel_44077/2490737532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['release_date'] = pd.to_datetime(movies['release_date'], format='%Y-%m-%d')

# %%
movies = movies[movies.budget.apply(lambda x: x.isnumeric())]
movies.budget = movies.budget.apply(lambda x: int(x))

# %%
# movies.production_countries.value_counts() # ассоц массив (уникальное значение : кол-во вхождений)

# movies[ [‘колонка1’, ‘коллонка2’, ‘колонка3’] ] # подтаблица только с указанными колонками
# movies.sort_values(by=‘колонка1’, ascending=False ) #сортировка по колонкам по убыванию
# movies.join(data_col, on=[‘название колонки’]) #объединить data с data_col по значениям указанной колонки


# series.sort_index() # сортировка по индексам
# series.min() # минимальное значение
# series.max() # максимальное значение
# series.mean() # среднее значение
# series.median() # медианой значение

# %%
from pathlib import Path  

datasets_to_save = {
    "countries_legend": countries_legend,
    "films_to_counries": films_to_counries_plural,
    "films_to_languages": films_to_languages_plural,
    "languages_legend": languages_legend,
    "films_to_genres": films_to_genres_plural,
    "genres_legend": genres_legend,
    "films_to_companies": films_to_companies_plural,
    "companies_legend": companies_legend,
    "films_to_collections": films_to_collections,
    "movies_stuff": movies_stuff,
    "prepared_movies": movies
}

path_to_my_datasets = "./my_datasets"

for(file_name, df) in datasets_to_save.items():
    filepath = Path(f'{path_to_my_datasets}/{file_name}.csv')  
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath, index=False)
